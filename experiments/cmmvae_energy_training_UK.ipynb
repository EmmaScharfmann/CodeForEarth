# %%
import numpy as np
import pandas as pd
import xarray as xr
import cfgrib

import utils
from package_name.evaluation import plots as eval_plots
from package_name.evaluation.utils import predict_clusters
from package_name.evaluation import metrics
from package_name.training.trainer import VAETrainer, VAEConfig
from package_name.training.finetuner import VAEFinetuner
from package_name.tuning.cross_validator import CrossValidator
from package_name.inference.predictor import VAEPredictor
from package_name.model.utils import sampling, LossFactorsConfig
from package_name.evaluation.pca_kmeans import PCAKmeansTrainer,  PCAKmeansPredictor

import matplotlib.pyplot as plt
plt.style.use('default')
# Out:
# /home/zilnora/.conda/envs/CodeForEarth/lib/python3.13/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789642674.526926  563624 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1789642674.527593  563624 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1789642674.571641  563624 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789642677.620327  563624 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1789642677.620954  563624 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Parameters

# %%
g0 = 9.80665
extended_winter_months = [11, 12, 1, 2, 3]
results_path = "/net/nitrogen/atmosdyn/zilnora/code_for_earth/our_results/CH/"
data_path = "/net/nitrogen/atmosdyn/zilnora/code_for_earth/our_data/wind/"
cluster_number = 8
original_dim = 575
pr_cluster_number = 8
batch_size = 128
epochs = 500

# %% [markdown]
# ## Data loading and pre-processing

# %%
#create clusters for country-wise energy data
path = data_path + "WON_country_wise.csv"

df_in = pd.read_csv(path, comment="#")

df_filtered = df_in.copy()
df_filtered["Date"] = pd.to_datetime(df_filtered["Date"])
df_filtered = df_filtered[(df_filtered["Date"].dt.year > 1980) & (df_filtered["Date"].dt.year < 2023)]
df_filtered = df_filtered[df_filtered["Date"].dt.month.isin(extended_winter_months)]

df_countries = df_filtered.drop(columns=["Date"])
df_countries = df_countries.dropna(axis=1, how="all").reset_index(drop=True)
df_countries = df_countries[["CH"]]

df_target, df_target_clusters = utils.calc_quantiles_UK(df_countries, cluster_number=pr_cluster_number, standardize=True)

#df_target_clusters.to_csv(data_path + "WON_clusters_norm.csv")
#df_target.to_csv(data_path + "WON_country_wise_norm.csv")
df_target_clusters.to_csv(data_path + "CH_8_clusters_norm.csv")
df_target.to_csv(data_path + "CH_country_wise_norm.csv")

#df_target_clusters = pd.read_csv(data_path + "WON_clusters_norm.csv", index_col=0)
#df_target = pd.read_csv(data_path + "WON_country_wise_norm.csv", index_col=0)

# %%
# Get training data
z500 = utils.preprocess_dataset(filename = "/net/nitrogen/atmosdyn/zilnora/code_for_earth/our_data/z500/era5_z500_daily_250_atlantic_1940_2022.nc",
                             variable_name = 'z',
                             multiplication_factor = 1/g0,
                             geographical_filter = utils.GeographicalFilter.EXTENDED_EUROPE,
                             months_filter = extended_winter_months,
                             anomalies = True,
                             normalization = False,
                             rolling_window = 5)

z500 = z500.where(z500['time.year'] > 1980, drop=True)
z500 = z500.where(z500['time.year'] < 2023, drop=True)


weights = np.cos(np.deg2rad(z500.latitude))
z500 = z500*weights
std_dev = z500.std()
z500 = z500/z500.std()

z500_reshaped = utils.reshape_data_for_clustering(z500)


# Get training data labels
target_labels = pd.read_csv(data_path + 'CH_8_clusters_norm.csv')
target_labels.columns = ['index', 'labels']

target_labels['values']=[1]*len(target_labels)
target_categorical_pd = pd.pivot_table(target_labels, values='values', index=['index'],
                    columns=['labels'], aggfunc=np.sum).fillna(0)
target_categorical = target_categorical_pd.values

# %%
#set training and testing data
training_indices = np.where(z500['time.year'] < 2015)[0]
testing_indices = np.where(z500['time.year'] >= 2015)[0]

z500_training = z500[training_indices]
z500_testing = z500[testing_indices]

z500_reshaped_training = z500_reshaped[training_indices]
z500_reshaped_testing = z500_reshaped[testing_indices]

target_categorical_training = target_categorical[training_indices]
target_categorical_testing = target_categorical[testing_indices]

df_target_training = df_target.iloc[training_indices]
df_target_testing = df_target.iloc[testing_indices]

# %%
print("count of each label", target_categorical_training.sum(axis=0)/target_categorical_training.sum())
# Out:
# count of each label [0.12796577 0.1201867  0.12427071 0.12465967 0.12504862 0.12640996
#  0.12563205 0.12582653]

# %% [markdown]
# ## Define model (single run)

# %%
config = VAEConfig(
    original_dim=original_dim,
    original_dim_target=pr_cluster_number,
    dim_layer1=256,
    dim_layer2=128,
    dim_layer3=64,
    activation="relu",
    cluster_number=cluster_number,
    latent_dim=10,#8,
    pr_cluster_number=pr_cluster_number,
    sampling_fn=sampling,
)

loss_config = LossFactorsConfig(
    vae_reconstruction_loss_factor=1,
    vae_regularisation_loss_factor=1,
    target_prediction_loss_factor=1,
    cluster_target_regularisation_loss_factor=1,#5
    mixture_regularization_loss_factor=1,#2,
    dirichlet_loss_factor=0.5 #1
)

vae = VAETrainer(cfg=config,  path_to_save_weights=results_path, loss_factors=loss_config)
vae.compile()

history = vae.fit(
    X=z500_training.values,
    y=target_categorical_training,
    epochs=epochs,
    batch_size=batch_size
)

vae.save_weights(results_path+'final_weights_UK_'+str(cluster_number)+'_4_5_training_test_500.weights.h5')
# Out:
# Epoch 1/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 26
#      22
#      23 vae = VAETrainer(cfg=config,  path_to_save_weights=results_path, loss_factors=loss_config)
#      24 vae.compile()
#      25
# ---> 26 history = vae.fit(
#      27     X=z500_training.values,
#      28     y=target_categorical_training,
#      29     epochs=epochs,
#
# File /net/nitrogen/atmosdyn/zilnora/code_for_earth/our_code_git/CodeForEarth/package_name/training/trainer.py:85, in VAETrainer.fit(self, X, y, epochs, batch_size)
#      78 train_ds = data_processor.format_input_to_dataset(
#      79     inputs=train_inputs, batch_size=batch_size
#      80 )
#      81 val_ds = data_processor.format_input_to_dataset(
#      82     inputs=val_inputs, batch_size=batch_size
#      83 )
# ---> 85 history = self._model.fit(
#      86     train_ds,
#      87     validation_data=val_ds,
#      88     epochs=epochs,
#      89 )
#      91 return history
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/framework/func_graph.py:1060, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057   return x
#    1059 _, original_func = tf_decorator.unwrap(python_func)
# -> 1060 func_outputs = python_func(*func_args, **func_kwargs)
#    1062 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063 # TensorArrays and `None`s.
#    1064 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/autograph/impl/api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py:154, in TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator(iterator)
#     150 @tf.autograph.experimental.do_not_convert
#     151 def multi_step_on_iterator(iterator):
#     152     if self.steps_per_execution == 1:
#     153         return tf.experimental.Optional.from_value(
# --> 154             one_step_on_data(iterator.get_next())
#     155         )
#     157     # the spec is set lazily during the tracing of `tf.while_loop`
#     158     empty_outputs = tf.experimental.Optional.empty(None)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py:125, in TensorFlowTrainer._autoconvert_optionals.<locals>.wrapper(data)
#     117 @functools.wraps(step_func)
#     118 def wrapper(data):
#     119     converted_data = tree.map_structure(
#     120         lambda i: (
#     121             None if isinstance(i, tf.experimental.Optional) else i
#     122         ),
#     123         data,
#     124     )
# --> 125     result = step_func(converted_data)
#     126     return result
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:906, in Function._call(self, *args, **kwds)
#     902     pass  # Fall through to cond-based initialization.
#     903   else:
#     904     # Lifting succeeded, so variables are initialized and we can run the
#     905     # no_variable_creation function.
# --> 906     return tracing_compilation.call_function(
#     907         args, kwds, self._no_variable_creation_config
#     908     )
#     909 else:
#     910   bound_args = self._concrete_variable_creation_fn.function_type.bind(
#     911       *args, **kwds
#     912   )
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:132, in call_function(args, kwargs, tracing_options)
#     130 args = args if args else ()
#     131 kwargs = kwargs if kwargs else {}
# --> 132 function = trace_function(
#     133     args=args, kwargs=kwargs, tracing_options=tracing_options
#     134 )
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/framework/func_graph.py:1060, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057   return x
#    1059 _, original_func = tf_decorator.unwrap(python_func)
# -> 1060 func_outputs = python_func(*func_args, **func_kwargs)
#    1062 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063 # TensorArrays and `None`s.
#    1064 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py:134, in TensorFlowTrainer._make_function.<locals>.one_step_on_data(data)
#     131 @tf.autograph.experimental.do_not_convert
#     132 def one_step_on_data(data):
#     133     """Runs a single training step on a batch of data."""
# --> 134     outputs = self.distribute_strategy.run(step_function, args=(data,))
#     135     outputs = reduce_per_replica(
#     136         outputs,
#     137         self.distribute_strategy,
#     138         reduction="auto",
#     139     )
#     140     return outputs
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/distribute/distribute_lib.py:1673, in StrategyBase.run(***failed resolving arguments***)
#    1668 with self.scope():
#    1669   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670   # applied when the caller is also in Eager mode.
#    1671   fn = autograph.tf_convert(
#    1672       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/distribute/distribute_lib.py:3263, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3261   kwargs = {}
#    3262 with self._container_strategy().scope():
# -> 3263   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/distribute/distribute_lib.py:4061, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4059 def _call_for_each_replica(self, fn, args, kwargs):
#    4060   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061     return fn(*args, **kwargs)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py:81, in TensorFlowTrainer.train_step(self, data)
#      79 if self.trainable_weights:
#      80     trainable_weights = self.trainable_weights
# ---> 81     gradients = tape.gradient(loss, trainable_weights)
#      83     # Update weights
#      84     self.optimizer.apply_gradients(zip(gradients, trainable_weights))
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/backprop.py:1066, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1060   output_gradients = (
#    1061       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1062           output_gradients))
#    1063   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1064                       for x in output_gradients]
# -> 1066 flat_grad = imperative_grad.imperative_grad(
#    1067     self._tape,
#    1068     flat_targets,
#    1069     flat_sources,
#    1070     output_gradients=output_gradients,
#    1071     sources_raw=flat_sources_raw,
#    1072     unconnected_gradients=unconnected_gradients)
#    1074 if not self._persistent:
#    1075   # Keep track of watched variables before setting tape to None
#    1076   self._watched_variables = self._tape.watched_variables()
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/eager/backprop.py:148, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     146     gradient_name_scope += forward_pass_name_scope + "/"
#     147   with ops.name_scope(gradient_name_scope):
# --> 148     return grad_fn(mock_op, *out_grads)
#     149 else:
#     150   return grad_fn(mock_op, *out_grads)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/ops/math_grad.py:767, in _LogGrad(op, grad)
#     765 with ops.control_dependencies([grad]):
#     766   x = math_ops.conj(x)
# --> 767   return grad * math_ops.reciprocal(x)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/ops/gen_math_ops.py:8288, in reciprocal(x, name)
#    8284   # Add nodes to the TensorFlow graph.
#    8285   try:
#    8286     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    8287         "Reciprocal", x=x, name=name)
# -> 8288   except (TypeError, ValueError):
#    8289     _result = _dispatch.dispatch(
#    8290           reciprocal, (), dict(x=x, name=name)
#    8291         )
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/framework/op_def_library.py:796, in _apply_op_helper(op_type_name, name, **keywords)
#     791 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     792                         if arg.is_ref]
#     793 with _MaybeColocateWith(must_colocate_inputs):
#     794   # Add Op to graph
#     795   # pylint: disable=protected-access
# --> 796   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     797                              name=scope, input_types=input_types,
#     798                              attrs=attr_protos, op_def=op_def)
#     800 # `outputs` is returned as a separate return value so that the output
#     801 # tensors can the `op` per se can be decoupled so that the
#     802 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     803 # for more details.
#     804 outputs = op.outputs
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/framework/func_graph.py:614, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     612   inp = self.capture(inp)
#     613   captured_inputs.append(inp)
# --> 614 return super()._create_op_internal(  # pylint: disable=protected-access
#     615     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     616     compute_device)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/framework/ops.py:2726, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2723 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2724 # Session.run call cannot occur between creating and mutating the op.
#    2725 with self._mutation_lock():
# -> 2726   ret = Operation.from_node_def(
#    2727       node_def,
#    2728       self,
#    2729       inputs=inputs,
#    2730       output_types=dtypes,
#    2731       control_inputs=control_inputs,
#    2732       input_types=input_types,
#    2733       original_op=self._default_original_op,
#    2734       op_def=op_def,
#    2735   )
#    2736   self._create_op_helper(ret, compute_device=compute_device)
#    2737 return ret
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/framework/ops.py:1223, in Operation.from_node_def(***failed resolving arguments***)
#    1221 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1222 self = Operation(c_op, SymbolicTensor)
# -> 1223 self._init(g)
#    1225 self._original_op = original_op
#    1227 # Post process for control flows.
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/framework/ops.py:1274, in Operation._init(self, graph)
#    1267 # Gradient function for this op. There are three ways to specify gradient
#    1268 # function, and first available gradient gets used, in the following order.
#    1269 # 1. self._gradient_function
#    1270 # 2. Gradient name registered by "_gradient_op_type" attribute.
#    1271 # 3. Gradient name registered by op.type.
#    1272 self._gradient_function = None
# -> 1274 self._init_outputs()
#    1275 self._id_value = self.graph._add_op(self)
#
# File ~/.conda/envs/CodeForEarth/lib/python3.13/site-packages/tensorflow/python/framework/ops.py:266, in SymbolicTensor.__new__(cls, op, value_index, dtype, unique_id)
#     264 if unique_id is None:
#     265   unique_id = uid()
# --> 266 return pywrap_tf_session.PyTensor.__new__(
#     267     SymbolicTensor, op, value_index, dtypes.as_dtype(dtype), unique_id
#     268 )
#
# KeyboardInterrupt:

# %%
history.history.items()
# Out:
# dict_items([('cluster_target_regularisation_loss', [0.2176520824432373, 0.3576667308807373, 0.35547688603401184, 0.32320600748062134, 0.3345683813095093, 0.3309175372123718, 0.33239054679870605, 0.3303939402103424, 0.363839715719223, 0.3790573179721832, 0.40001818537712097, 0.41922304034233093, 0.4290669858455658, 0.4459705352783203, 0.46973124146461487, 0.4789344072341919, 0.4962989091873169, 0.5110528469085693, 0.5257903337478638, 0.5398083925247192, 0.549964964389801, 0.5583882927894592, 0.5602747201919556, 0.5669173002243042, 0.5848475694656372, 0.5827121734619141, 0.5936012268066406, 0.6093902587890625, 0.6098116040229797, 0.6166756749153137, 0.6262576580047607, 0.6301619410514832, 0.6280925869941711, 0.6304266452789307, 0.6330678462982178, 0.6468984484672546, 0.651210606098175, 0.6510310173034668, 0.6475028395652771, 0.65055912733078, 0.6504472494125366, 0.6568486094474792, 0.6525920033454895, 0.6532784104347229, 0.6582854390144348, 0.6594210863113403, 0.6545095443725586, 0.6573092937469482, 0.6584469676017761, 0.655575156211853, 0.6488579511642456, 0.6488780975341797, 0.6493014097213745, 0.648388683795929, 0.6405678391456604, 0.6390547156333923, 0.6328421235084534, 0.6358837485313416, 0.6416283845901489, 0.6386107802391052, 0.6450017094612122, 0.6448086500167847, 0.6260544657707214, 0.6245965957641602, 0.620232105255127, 0.6085888743400574, 0.6186867952346802, 0.6169098615646362, 0.6223829388618469, 0.6087720990180969, 0.6056225895881653, 0.6060114502906799, 0.595166802406311, 0.6042167544364929, 0.593232274055481, 0.5885857939720154, 0.5794451236724854, 0.5644864439964294, 0.5708267092704773, 0.5717616081237793, 0.5803366303443909, 0.5714682936668396, 0.563504695892334, 0.5640681982040405, 0.5678755640983582, 0.5648941993713379, 0.5518834590911865, 0.5479182004928589, 0.5432626605033875, 0.5465331673622131, 0.5524123311042786, 0.5459797978401184, 0.5433704853057861, 0.541935384273529, 0.5341078042984009, 0.542330265045166, 0.5291518568992615, 0.5282672047615051, 0.5287356972694397, 0.5313056111335754, 0.530767560005188, 0.5196647047996521, 0.5206326842308044, 0.5211389660835266, 0.5201706886291504, 0.5110916495323181, 0.520477294921875, 0.5143831372261047, 0.5058228969573975, 0.5057454705238342, 0.49913540482521057, 0.5076127648353577, 0.5030807852745056, 0.5009012222290039, 0.5047770142555237, 0.48833250999450684, 0.4929118752479553, 0.48474636673927307, 0.47917068004608154, 0.4874119460582733, 0.48377490043640137, 0.48294028639793396, 0.47915366291999817, 0.4733498692512512, 0.47564616799354553, 0.4698921740055084, 0.4728102385997772, 0.482121080160141, 0.4740614593029022, 0.47267571091651917, 0.46906864643096924, 0.46129563450813293, 0.46608033776283264, 0.47378525137901306, 0.4531208574771881, 0.45822200179100037, 0.46590685844421387, 0.4621802568435669, 0.4527086913585663, 0.4642982482910156, 0.4527232348918915, 0.44872382283210754, 0.44332295656204224, 0.45689043402671814, 0.4582172632217407, 0.45674026012420654, 0.4459013342857361, 0.45285800099372864, 0.438066691160202, 0.43351733684539795, 0.43315860629081726, 0.43805214762687683, 0.4312592148780823, 0.4340496361255646, 0.43004101514816284, 0.445321261882782, 0.43126457929611206, 0.4331817030906677, 0.4349198043346405, 0.4262142777442932, 0.4188935458660126, 0.4238099157810211, 0.43123289942741394, 0.4243330657482147, 0.4288153052330017, 0.41175541281700134, 0.4231105446815491, 0.41733548045158386, 0.41474276781082153, 0.4413430392742157, 0.4216976761817932, 0.412783682346344, 0.42591601610183716, 0.414396733045578, 0.4096524119377136, 0.4009276032447815, 0.41663259267807007, 0.41016486287117004, 0.4085254371166229, 0.4136658012866974, 0.4042262136936188, 0.40888527035713196, 0.41154178977012634, 0.4165664613246918, 0.3936704695224762, 0.41155385971069336, 0.4038536846637726, 0.40335312485694885, 0.39738261699676514, 0.3925320506095886, 0.38160350918769836, 0.3844498097896576, 0.39522305130958557, 0.3920595347881317, 0.3950820863246918, 0.39900195598602295, 0. ...

# %% [markdown]
# ## Plot training and validation losses

# %%
utils.plot_all_losses(loss_terms=history.history.items())

# %% [markdown]
# ## Cross validation

# %%
vae = VAETrainer(cfg=config,  path_to_save_weights=results_path, loss_factors=loss_config)
vae.compile()

cross_validator = CrossValidator(vae=vae,filepath=results_path,cluster_number=cluster_number,n_runs=10)
histories = cross_validator.run(X=z500_training.values,y=target_categorical_training,epochs=epochs, batch_size=batch_size)
# Out:
# /home/zilnora/.conda/envs/CodeForEarth/lib/python3.13/site-packages/keras/src/saving/saving_lib.py:798: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 0 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Epoch 1/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - cluster_target_regularisation_loss: 0.2426 - mixture_regularization_loss: 8.8187 - reconstruction_loss: 502.5109 - target_prediction_loss: 18.7809 - total_loss: 540.1179 - vae_regularisation_loss: 9.7649 - val_cluster_target_regularisation_loss: 0.4026 - val_mixture_regularization_loss: 8.7396 - val_reconstruction_loss: 390.4331 - val_target_prediction_loss: 19.4641 - val_total_loss: 437.8665 - val_vae_regularisation_loss: 18.8270
# Epoch 2/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.3522 - mixture_regularization_loss: 8.7123 - reconstruction_loss: 305.6963 - target_prediction_loss: 19.7756 - total_loss: 354.8339 - vae_regularisation_loss: 20.2976 - val_cluster_target_regularisation_loss: 0.3214 - val_mixture_regularization_loss: 8.6727 - val_reconstruction_loss: 248.6628 - val_target_prediction_loss: 19.9502 - val_total_loss: 298.1939 - val_vae_regularisation_loss: 20.5868
# Epoch 3/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 0.3438 - mixture_regularization_loss: 8.6233 - reconstruction_loss: 237.2379 - target_prediction_loss: 18.8801 - total_loss: 284.1320 - vae_regularisation_loss: 19.0469 - val_cluster_target_regularisation_loss: 0.3541 - val_mixture_regularization_loss: 8.5905 - val_reconstruction_loss: 232.3959 - val_target_prediction_loss: 18.2750 - val_total_loss: 277.3748 - val_vae_regularisation_loss: 17.7595
# Epoch 4/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - cluster_target_regularisation_loss: 0.3454 - mixture_regularization_loss: 8.5626 - reconstruction_loss: 223.9518 - target_prediction_loss: 18.0003 - total_loss: 268.7946 - vae_regularisation_loss: 17.9346 - val_cluster_target_regularisation_loss: 0.3440 - val_mixture_regularization_loss: 8.5397 - val_reconstruction_loss: 218.3990 - val_target_prediction_loss: 17.8410 - val_total_loss: 262.7513 - val_vae_regularisation_loss: 17.6276
# Epoch 5/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - cluster_target_regularisation_loss: 0.3644 - mixture_regularization_loss: 8.5192 - reconstruction_loss: 201.8084 - target_prediction_loss: 17.6001 - total_loss: 247.5486 - vae_regularisation_loss: 19.2564 - val_cluster_target_regularisation_loss: 0.3940 - val_mixture_regularization_loss: 8.5038 - val_reconstruction_loss: 188.6046 - val_target_prediction_loss: 17.7561 - val_total_loss: 234.9313 - val_vae_regularisation_loss: 19.6728
# Epoch 6/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 0.3744 - mixture_regularization_loss: 8.4743 - reconstruction_loss: 182.3140 - target_prediction_loss: 17.1581 - total_loss: 227.9403 - vae_regularisation_loss: 19.6195 - val_cluster_target_regularisation_loss: 0.4159 - val_mixture_regularization_loss: 8.4637 - val_reconstruction_loss: 176.3025 - val_target_prediction_loss: 17.3636 - val_total_loss: 222.5457 - val_vae_regularisation_loss: 20.0001
# Epoch 7/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 0.4192 - mixture_regularization_loss: 8.4437 - reconstruction_loss: 164.3561 - target_prediction_loss: 17.0950 - total_loss: 210.3167 - vae_regularisation_loss: 20.0027 - val_cluster_target_regularisation_loss: 0.4459 - val_mixture_regularization_loss: 8.4360 - val_reconstruction_loss: 155.0891 - val_target_prediction_loss: 17.2894 - val_total_loss: 201.8085 - val_vae_regularisation_loss: 20.5482
# Epoch 8/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 0.4288 - mixture_regularization_loss: 8.4201 - reconstruction_loss: 147.9987 - target_prediction_loss: 16.8889 - total_loss: 194.3685 - vae_regularisation_loss: 20.6319 - val_cluster_target_regularisation_loss: 0.4525 - val_mixture_regularization_loss: 8.4116 - val_reconstruction_loss: 144.1052 - val_target_prediction_loss: 16.8809 - val_total_loss: 190.3101 - val_vae_regularisation_loss: 20.4598
# Epoch 9/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 0.4719 - mixture_regularization_loss: 8.4008 - reconstruction_loss: 140.3344 - target_prediction_loss: 16.6309 - total_loss: 186.7308 - vae_regularisation_loss: 20.8926 - val_cluster_target_regularisation_loss: 0.5155 - val_mixture_regularization_loss: 8.4028 - val_reconstruction_loss: 138.6965 - val_target_prediction_loss: 16.9910 - val_total_loss: 185.5309 - val_vae_regularisation_loss: 20.9252
# Epoch 10/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 0.4908 - mixture_regularization_loss: 8.3855 - reconstruction_loss: 132.0536 - target_prediction_loss: 16.4067 - total_loss: 178.3560 - vae_regularisation_loss: 21.0194 - val_cluster_target_regularisation_loss: 0.5169 - val_mixture_regularization_loss: 8.3942 - val_reconstruction_loss: 128.4684 - val_target_prediction_loss: 16.4893 - val_total_loss: 174.1039 - val_vae_regularisation_loss: 20.2350
# Epoch 11/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 0.5018 - mixture_regularization_loss: 8.3804 - reconstruction_loss: 123.5018 - target_prediction_loss: 16.2459 - total_loss: 169.6235 - vae_regularisation_loss: 20.9936 - val_cluster_target_regularisation_loss: 0.5268 - val_mixture_regularization_loss: 8.3835 - val_reconstruction_loss: 120.3031 - val_target_prediction_loss: 16.4006 - val_total_loss: 166.4628 - val_vae_regularisation_loss: 20.8490
# Epoch 12/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 0.5218 - mixture_regularization_loss: 8.3696 - reconstruction_loss: 118.3834 - target_prediction_loss: 16.0665 - total_loss: 164.3383 - vae_regularisation_loss: 20.9970 - val_cluster_target_regularisation_loss: 0.5438 - val_mixture_regularization_loss: 8.3750 - val_reconstruction_loss: 115.9208 - val_target_prediction_loss: 16.4433 - val_total_loss: 162.4427 - val_vae_regularisation_loss: 21.1598
# Epoch 13/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 0.5408 - mixture_regularization_loss: 8.3622 - reconstruction_loss: 114.2552 - target_prediction_loss: 15.9023 - total_loss: 160.1228 - vae_regularisation_loss: 21.0623 - val_cluster_target_regularisation_loss: 0.5779 - val_mixture_regularization_loss: 8.3733 - val_reconstruction_loss: 115.7021 - val_target_prediction_loss: 16.1436 - val_total_loss: 161.3111 - val_vae_regularisation_loss: 20.5142
# Epoch 14/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 0.5676 - mixture_regularization_loss: 8.3607 - reconstruction_loss: 112.6985 - target_prediction_loss: 15.7590 - total_loss: 157.8164 - vae_regularisation_loss: 20.4305 - val_cluster_target_regularisation_loss: 0.6005 - val_mixture_regularization_loss: 8.3692 - val_reconstruction_loss: 114.2985 - val_target_prediction_loss: 16.0461 - val_total_loss: 159.5752 - val_vae_regularisation_loss: 20.2609
# Epoch 15/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 0.5890 - mixture_regularization_loss: 8.3565 - reconstruction_loss: 111.8445 - target_prediction_loss: 15.7786 - total_loss: 157.0681 - vae_regularisation_loss: 20.4995 - val_cluster_target_regularisation_loss: 0.6157 - val_mixture_regularization_loss: 8.3627 - val_reconstruction_loss: 110.0139 - val_target_prediction_loss: 16.0035 - val_total_loss: 155.0630 - val_vae_regularisation_loss: 20.0672
# Epoch 16/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.6066 - mixture_regularization_loss: 8.3524 - reconstruction_loss: 108.3518 - target_prediction_loss: 15.5389 - total_loss: 152.9589 - vae_regularisation_loss: 20.1092 - val_cluster_target_regularisation_loss: 0.6414 - val_mixture_regularization_loss: 8.3650 - val_reconstruction_loss: 109.2736 - val_target_prediction_loss: 15.9900 - val_total_loss: 153.9384 - val_vae_regularisation_loss: 19.6684
# Epoch 17/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - cluster_target_regularisation_loss: 0.6439 - mixture_regularization_loss: 8.3536 - reconstruction_loss: 108.5552 - target_prediction_loss: 15.5196 - total_loss: 153.2187 - vae_regularisation_loss: 20.1464 - val_cluster_target_regularisation_loss: 0.6898 - val_mixture_regularization_loss: 8.3638 - val_reconstruction_loss: 110.6278 - val_target_prediction_loss: 15.9874 - val_total_loss: 156.1834 - val_vae_regularisation_loss: 20.5147
# Epoch 18/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - cluster_target_regularisation_loss: 0.6675 - mixture_regularization_loss: 8.3485 - reconstruction_loss: 107.2622 - target_prediction_loss: 15.5387 - total_loss: 151.7808 - vae_regularisation_loss: 19.9640 - val_cluster_target_regularisation_loss: 0.7151 - val_mixture_regularization_loss: 8.3647 - val_reconstruction_loss: 107.7550 - val_target_prediction_loss: 15.8280 - val_total_loss: 152.8316 - val_vae_regularisation_loss: 20.1687
# Epoch 19/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - cluster_target_regularisation_loss: 0.6933 - mixture_regularization_loss: 8.3493 - reconstruction_loss: 104.1562 - target_prediction_loss: 15.4880 - total_loss: 148.5529 - vae_regularisation_loss: 19.8660 - val_cluster_target_regularisation_loss: 0.7361 - val_mixture_regularization_loss: 8.3598 - val_reconstruction_loss: 105.6434 - val_target_prediction_loss: 15.6980 - val_total_loss: 150.5357 - val_vae_regularisation_loss: 20.0984
# Epoch 20/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - cluster_target_regularisation_loss: 0.7212 - mixture_regularization_loss: 8.3470 - reconstruction_loss: 101.6159 - target_prediction_loss: 15.3879 - total_loss: 145.7095 - vae_regularisation_loss: 19.6376 - val_cluster_target_regularisation_loss: 0.7565 - val_mixture_regularization_loss: 8.3624 - val_reconstruction_loss: 102.8108 - val_target_prediction_loss: 15.7132 - val_total_loss: 147.6790 - val_vae_regularisation_loss: 20.0361
# Epoch 21/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 0.7512 - mixture_regularization_loss: 8.3479 - reconstruction_loss: 98.4339 - target_prediction_loss: 15.4620 - total_loss: 143.2348 - vae_regularisation_loss: 20.2398 - val_cluster_target_regularisation_loss: 0.7836 - val_mixture_regularization_loss: 8.3600 - val_reconstruction_loss: 99.9774 - val_target_prediction_loss: 15.6969 - val_total_loss: 144.7807 - val_vae_regularisation_loss: 19.9629
# Epoch 22/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - cluster_target_regularisation_loss: 0.7672 - mixture_regularization_loss: 8.3442 - reconstruction_loss: 96.3190 - target_prediction_loss: 15.4213 - total_loss: 140.7286 - vae_regularisation_loss: 19.8768 - val_cluster_target_regularisation_loss: 0.7754 - val_mixture_regularization_loss: 8.3544 - val_reconstruction_loss: 98.1466 - val_target_prediction_loss: 15.7184 - val_total_loss: 142.9764 - val_vae_regularisation_loss: 19.9817
# Epoch 23/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - cluster_target_regularisation_loss: 0.7804 - mixture_regularization_loss: 8.3421 - reconstruction_loss: 94.8657 - target_prediction_loss: 15.4231 - total_loss: 139.2487 - vae_regularisation_loss: 19.8374 - val_cluster_target_regularisation_loss: 0.8254 - val_mixture_regularization_loss: 8.3579 - val_reconstruction_loss: 96.0377 - val_target_prediction_loss: 15.8272 - val_total_loss: 141.2808 - val_vae_regularisation_loss: 20.2326
# Epoch 24/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - cluster_target_regularisation_loss: 0.8093 - mixture_regularization_loss: 8.3425 - reconstruction_loss: 93.1899 - target_prediction_loss: 15.4815 - total_loss: 137.9203 - vae_regularisation_loss: 20.0971 - val_cluster_target_regularisation_loss: 0.8292 - val_mixture_regularization_loss: 8.3562 - val_reconstruction_loss: 97.0886 - val_target_prediction_loss: 15.6449 - val_total_loss: 141.4455 - val_vae_regularisation_loss: 19.5266
# Epoch 25/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.8193 - mixture_regularization_loss: 8.3421 - reconstruction_loss: 93.5053 - target_prediction_loss: 15.3216 - total_loss: 137.4958 - vae_regularisation_loss: 19.5076 - val_cluster_target_regularisation_loss: 0.8401 - val_mixture_regularization_loss: 8.3539 - val_reconstruction_loss: 94.2076 - val_target_prediction_loss: 15.6710 - val_total_loss: 138.6156 - val_vae_regularisation_loss: 19.5431
# Epoch 26/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 0.8456 - mixture_regularization_loss: 8.3409 - reconstruction_loss: 91.5342 - target_prediction_loss: 15.2821 - total_loss: 135.9120 - vae_regularisation_loss: 19.9092 - val_cluster_target_regularisation_loss: 0.8547 - val_mixture_regularization_loss: 8.3465 - val_reconstruction_loss: 97.8027 - val_target_prediction_loss: 15.5901 - val_total_loss: 141.8594 - val_vae_regularisation_loss: 19.2655
# Epoch 27/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 0.8578 - mixture_regularization_loss: 8.3381 - reconstruction_loss: 90.0234 - target_prediction_loss: 15.3317 - total_loss: 133.9997 - vae_regularisation_loss: 19.4487 - val_cluster_target_regularisation_loss: 0.8889 - val_mixture_regularization_loss: 8.3496 - val_reconstruction_loss: 93.5419 - val_target_prediction_loss: 15.5613 - val_total_loss: 137.4520 - val_vae_regularisation_loss: 19.1103
# Epoch 28/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.8856 - mixture_regularization_loss: 8.3390 - reconstruction_loss: 89.3835 - target_prediction_loss: 15.2676 - total_loss: 133.1725 - vae_regularisation_loss: 19.2968 - val_cluster_target_regularisation_loss: 0.8947 - val_mixture_regularization_loss: 8.3477 - val_reconstruction_loss: 93.4533 - val_target_prediction_loss: 15.5657 - val_total_loss: 137.4571 - val_vae_regularisation_loss: 19.1958
# Epoch 29/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.8855 - mixture_regularization_loss: 8.3382 - reconstruction_loss: 88.9373 - target_prediction_loss: 15.2667 - total_loss: 132.3646 - vae_regularisation_loss: 18.9369 - val_cluster_target_regularisation_loss: 0.9053 - val_mixture_regularization_loss: 8.3481 - val_reconstruction_loss: 93.9849 - val_target_prediction_loss: 15.7242 - val_total_loss: 137.4991 - val_vae_regularisation_loss: 18.5366
# Epoch 30/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 0.9029 - mixture_regularization_loss: 8.3387 - reconstruction_loss: 88.2075 - target_prediction_loss: 15.2451 - total_loss: 131.8866 - vae_regularisation_loss: 19.1924 - val_cluster_target_regularisation_loss: 0.9312 - val_mixture_regularization_loss: 8.3518 - val_reconstruction_loss: 92.5349 - val_target_prediction_loss: 15.5286 - val_total_loss: 136.4777 - val_vae_regularisation_loss: 19.1311
# Epoch 31/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 0.9360 - mixture_regularization_loss: 8.3381 - reconstruction_loss: 88.2292 - target_prediction_loss: 15.3159 - total_loss: 132.0094 - vae_regularisation_loss: 19.1902 - val_cluster_target_regularisation_loss: 0.9389 - val_mixture_regularization_loss: 8.3522 - val_reconstruction_loss: 91.2191 - val_target_prediction_loss: 15.5946 - val_total_loss: 134.8682 - val_vae_regularisation_loss: 18.7633
# Epoch 32/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.9415 - mixture_regularization_loss: 8.3364 - reconstruction_loss: 86.4409 - target_prediction_loss: 15.2999 - total_loss: 130.1931 - vae_regularisation_loss: 19.1744 - val_cluster_target_regularisation_loss: 0.9650 - val_mixture_regularization_loss: 8.3503 - val_reconstruction_loss: 90.6361 - val_target_prediction_loss: 15.5990 - val_total_loss: 134.3497 - val_vae_regularisation_loss: 18.7993
# Epoch 33/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - cluster_target_regularisation_loss: 0.9491 - mixture_regularization_loss: 8.3365 - reconstruction_loss: 86.3660 - target_prediction_loss: 15.2113 - total_loss: 129.6894 - vae_regularisation_loss: 18.8266 - val_cluster_target_regularisation_loss: 0.9750 - val_mixture_regularization_loss: 8.3464 - val_reconstruction_loss: 90.6835 - val_target_prediction_loss: 15.6566 - val_total_loss: 134.4525 - val_vae_regularisation_loss: 18.7909
# Epoch 34/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - cluster_target_regularisation_loss: 0.9646 - mixture_regularization_loss: 8.3358 - reconstruction_loss: 85.1150 - target_prediction_loss: 15.2220 - total_loss: 128.3992 - vae_regularisation_loss: 18.7618 - val_cluster_target_regularisation_loss: 0.9874 - val_mixture_regularization_loss: 8.3478 - val_reconstruction_loss: 88.2542 - val_target_prediction_loss: 15.6185 - val_total_loss: 132.1893 - val_vae_regularisation_loss: 18.9815
# Epoch 35/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 0.9816 - mixture_regularization_loss: 8.3364 - reconstruction_loss: 84.9931 - target_prediction_loss: 15.2294 - total_loss: 128.3912 - vae_regularisation_loss: 18.8507 - val_cluster_target_regularisation_loss: 0.9915 - val_mixture_regularization_loss: 8.3492 - val_reconstruction_loss: 87.7860 - val_target_prediction_loss: 15.5535 - val_total_loss: 131.6449 - val_vae_regularisation_loss: 18.9646
# Epoch 36/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 0.9827 - mixture_regularization_loss: 8.3361 - reconstruction_loss: 84.4353 - target_prediction_loss: 15.2187 - total_loss: 127.7616 - vae_regularisation_loss: 18.7888 - val_cluster_target_regularisation_loss: 1.0017 - val_mixture_regularization_loss: 8.3463 - val_reconstruction_loss: 89.1558 - val_target_prediction_loss: 15.5817 - val_total_loss: 133.2642 - val_vae_regularisation_loss: 19.1787
# Epoch 37/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 1.0001 - mixture_regularization_loss: 8.3353 - reconstruction_loss: 84.3576 - target_prediction_loss: 15.2139 - total_loss: 127.7840 - vae_regularisation_loss: 18.8771 - val_cluster_target_regularisation_loss: 1.0086 - val_mixture_regularization_loss: 8.3441 - val_reconstruction_loss: 89.0860 - val_target_prediction_loss: 15.4720 - val_total_loss: 132.0833 - val_vae_regularisation_loss: 18.1727
# Epoch 38/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 1.0101 - mixture_regularization_loss: 8.3359 - reconstruction_loss: 83.2830 - target_prediction_loss: 15.2368 - total_loss: 126.5362 - vae_regularisation_loss: 18.6704 - val_cluster_target_regularisation_loss: 1.0282 - val_mixture_regularization_loss: 8.3428 - val_reconstruction_loss: 88.9719 - val_target_prediction_loss: 15.5943 - val_total_loss: 132.8057 - val_vae_regularisation_loss: 18.8685
# Epoch 39/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.0208 - mixture_regularization_loss: 8.3362 - reconstruction_loss: 83.7007 - target_prediction_loss: 15.2176 - total_loss: 126.8999 - vae_regularisation_loss: 18.6246 - val_cluster_target_regularisation_loss: 1.0399 - val_mixture_regularization_loss: 8.3424 - val_reconstruction_loss: 87.0848 - val_target_prediction_loss: 15.5705 - val_total_loss: 130.9109 - val_vae_regularisation_loss: 18.8733
# Epoch 40/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - cluster_target_regularisation_loss: 1.0404 - mixture_regularization_loss: 8.3356 - reconstruction_loss: 82.3184 - target_prediction_loss: 15.2191 - total_loss: 125.7882 - vae_regularisation_loss: 18.8745 - val_cluster_target_regularisation_loss: 1.0471 - val_mixture_regularization_loss: 8.3443 - val_reconstruction_loss: 85.8076 - val_target_prediction_loss: 15.4516 - val_total_loss: 129.4700 - val_vae_regularisation_loss: 18.8195
# Epoch 41/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - cluster_target_regularisation_loss: 1.0451 - mixture_regularization_loss: 8.3358 - reconstruction_loss: 80.3184 - target_prediction_loss: 15.2275 - total_loss: 123.8066 - vae_regularisation_loss: 18.8797 - val_cluster_target_regularisation_loss: 1.0373 - val_mixture_regularization_loss: 8.3474 - val_reconstruction_loss: 85.7916 - val_target_prediction_loss: 15.4491 - val_total_loss: 128.9446 - val_vae_regularisation_loss: 18.3192
# Epoch 42/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 1.0345 - mixture_regularization_loss: 8.3357 - reconstruction_loss: 80.5983 - target_prediction_loss: 15.2366 - total_loss: 123.9409 - vae_regularisation_loss: 18.7358 - val_cluster_target_regularisation_loss: 1.0620 - val_mixture_regularization_loss: 8.3468 - val_reconstruction_loss: 84.3691 - val_target_prediction_loss: 15.4696 - val_total_loss: 127.7088 - val_vae_regularisation_loss: 18.4612
# Epoch 43/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 1.0546 - mixture_regularization_loss: 8.3353 - reconstruction_loss: 78.5329 - target_prediction_loss: 15.1732 - total_loss: 122.4087 - vae_regularisation_loss: 19.3128 - val_cluster_target_regularisation_loss: 1.0598 - val_mixture_regularization_loss: 8.3441 - val_reconstruction_loss: 82.4589 - val_target_prediction_loss: 15.5171 - val_total_loss: 126.6002 - val_vae_regularisation_loss: 19.2203
# Epoch 44/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 1.0624 - mixture_regularization_loss: 8.3365 - reconstruction_loss: 78.7738 - target_prediction_loss: 15.1938 - total_loss: 122.6142 - vae_regularisation_loss: 19.2478 - val_cluster_target_regularisation_loss: 1.0779 - val_mixture_regularization_loss: 8.3441 - val_reconstruction_loss: 82.5291 - val_target_prediction_loss: 15.4635 - val_total_loss: 127.0308 - val_vae_regularisation_loss: 19.6162
# Epoch 45/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 1.0744 - mixture_regularization_loss: 8.3363 - reconstruction_loss: 77.1239 - target_prediction_loss: 15.0658 - total_loss: 121.0469 - vae_regularisation_loss: 19.4466 - val_cluster_target_regularisation_loss: 1.0871 - val_mixture_regularization_loss: 8.3450 - val_reconstruction_loss: 82.1039 - val_target_prediction_loss: 15.5904 - val_total_loss: 126.3768 - val_vae_regularisation_loss: 19.2505
# Epoch 46/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 1.0782 - mixture_regularization_loss: 8.3366 - reconstruction_loss: 75.8289 - target_prediction_loss: 15.2195 - total_loss: 119.8408 - vae_regularisation_loss: 19.3776 - val_cluster_target_regularisation_loss: 1.0981 - val_mixture_regularization_loss: 8.3500 - val_reconstruction_loss: 78.9361 - val_target_prediction_loss: 15.4570 - val_total_loss: 122.8907 - val_vae_regularisation_loss: 19.0496
# Epoch 47/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - cluster_target_regularisation_loss: 1.0827 - mixture_regularization_loss: 8.3374 - reconstruction_loss: 75.1073 - target_prediction_loss: 15.1416 - total_loss: 118.6576 - vae_regularisation_loss: 18.9886 - val_cluster_target_regularisation_loss: 1.1137 - val_mixture_regularization_loss: 8.3493 - val_reconstruction_loss: 81.0748 - val_target_prediction_loss: 15.6682 - val_total_loss: 125.4508 - val_vae_regularisation_loss: 19.2447
# Epoch 48/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - cluster_target_regularisation_loss: 1.0946 - mixture_regularization_loss: 8.3379 - reconstruction_loss: 76.1623 - target_prediction_loss: 15.1285 - total_loss: 120.0949 - vae_regularisation_loss: 19.3716 - val_cluster_target_regularisation_loss: 1.1143 - val_mixture_regularization_loss: 8.3472 - val_reconstruction_loss: 78.3969 - val_target_prediction_loss: 15.5239 - val_total_loss: 122.9884 - val_vae_regularisation_loss: 19.6062
# Epoch 49/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.1074 - mixture_regularization_loss: 8.3358 - reconstruction_loss: 73.8772 - target_prediction_loss: 15.1961 - total_loss: 117.9735 - vae_regularisation_loss: 19.4571 - val_cluster_target_regularisation_loss: 1.0867 - val_mixture_regularization_loss: 8.3446 - val_reconstruction_loss: 80.4746 - val_target_prediction_loss: 15.5519 - val_total_loss: 124.5267 - val_vae_regularisation_loss: 19.0689
# Epoch 50/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 1.1011 - mixture_regularization_loss: 8.3356 - reconstruction_loss: 73.3862 - target_prediction_loss: 15.1458 - total_loss: 117.1032 - vae_regularisation_loss: 19.1346 - val_cluster_target_regularisation_loss: 1.1013 - val_mixture_regularization_loss: 8.3488 - val_reconstruction_loss: 81.5858 - val_target_prediction_loss: 15.4066 - val_total_loss: 125.5710 - val_vae_regularisation_loss: 19.1285
# Epoch 51/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 1.1040 - mixture_regularization_loss: 8.3365 - reconstruction_loss: 73.8768 - target_prediction_loss: 15.1129 - total_loss: 117.6713 - vae_regularisation_loss: 19.2411 - val_cluster_target_regularisation_loss: 1.1153 - val_mixture_regularization_loss: 8.3442 - val_reconstruction_loss: 78.8942 - val_target_prediction_loss: 15.4704 - val_total_loss: 122.6453 - val_vae_regularisation_loss: 18.8213
# Epoch 52/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.1199 - mixture_regularization_loss: 8.3377 - reconstruction_loss: 73.0658 - target_prediction_loss: 15.1379 - total_loss: 116.6252 - vae_regularisation_loss: 18.9638 - val_cluster_target_regularisation_loss: 1.1212 - val_mixture_regularization_loss: 8.3507 - val_reconstruction_loss: 78.9653 - val_target_prediction_loss: 15.4592 - val_total_loss: 122.8136 - val_vae_regularisation_loss: 18.9172
# Epoch 53/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - cluster_target_regularisation_loss: 1.1173 - mixture_regularization_loss: 8.3357 - reconstruction_loss: 73.1724 - target_prediction_loss: 15.0254 - total_loss: 116.9344 - vae_regularisation_loss: 19.2836 - val_cluster_target_regularisation_loss: 1.1277 - val_mixture_regularization_loss: 8.3461 - val_reconstruction_loss: 79.0396 - val_target_prediction_loss: 15.4949 - val_total_loss: 122.9049 - val_vae_regularisation_loss: 18.8966
# Epoch 54/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 1.1235 - mixture_regularization_loss: 8.3371 - reconstruction_loss: 72.9873 - target_prediction_loss: 15.0871 - total_loss: 116.7396 - vae_regularisation_loss: 19.2046 - val_cluster_target_regularisation_loss: 1.1402 - val_mixture_regularization_loss: 8.3489 - val_reconstruction_loss: 77.1284 - val_target_prediction_loss: 15.3902 - val_total_loss: 120.7476 - val_vae_regularisation_loss: 18.7398
# Epoch 55/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - cluster_target_regularisation_loss: 1.1272 - mixture_regularization_loss: 8.3370 - reconstruction_loss: 72.1644 - target_prediction_loss: 15.0342 - total_loss: 115.7608 - vae_regularisation_loss: 19.0979 - val_cluster_target_regularisation_loss: 1.1478 - val_mixture_regularization_loss: 8.3472 - val_reconstruction_loss: 76.7671 - val_target_prediction_loss: 15.4580 - val_total_loss: 121.0283 - val_vae_regularisation_loss: 19.3082
# Epoch 56/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - cluster_target_regularisation_loss: 1.1405 - mixture_regularization_loss: 8.3380 - reconstruction_loss: 72.5522 - target_prediction_loss: 15.0702 - total_loss: 116.4000 - vae_regularisation_loss: 19.2991 - val_cluster_target_regularisation_loss: 1.1323 - val_mixture_regularization_loss: 8.3496 - val_reconstruction_loss: 77.1421 - val_target_prediction_loss: 15.3606 - val_total_loss: 121.3223 - val_vae_regularisation_loss: 19.3379
# Epoch 57/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - cluster_target_regularisation_loss: 1.1416 - mixture_regularization_loss: 8.3364 - reconstruction_loss: 71.5851 - target_prediction_loss: 15.0255 - total_loss: 115.0868 - vae_regularisation_loss: 18.9982 - val_cluster_target_regularisation_loss: 1.1459 - val_mixture_regularization_loss: 8.3530 - val_reconstruction_loss: 76.0485 - val_target_prediction_loss: 15.4818 - val_total_loss: 119.6878 - val_vae_regularisation_loss: 18.6586
# Epoch 58/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 1.1421 - mixture_regularization_loss: 8.3365 - reconstruction_loss: 71.1733 - target_prediction_loss: 15.0682 - total_loss: 114.8595 - vae_regularisation_loss: 19.1394 - val_cluster_target_regularisation_loss: 1.1634 - val_mixture_regularization_loss: 8.3491 - val_reconstruction_loss: 79.3126 - val_target_prediction_loss: 15.3788 - val_total_loss: 123.3104 - val_vae_regularisation_loss: 19.1066
# Epoch 59/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.1407 - mixture_regularization_loss: 8.3365 - reconstruction_loss: 71.2737 - target_prediction_loss: 15.0575 - total_loss: 114.8123 - vae_regularisation_loss: 19.0039 - val_cluster_target_regularisation_loss: 1.1633 - val_mixture_regularization_loss: 8.3526 - val_reconstruction_loss: 76.5570 - val_target_prediction_loss: 15.3877 - val_total_loss: 120.4699 - val_vae_regularisation_loss: 19.0094
# Epoch 60/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 1.1596 - mixture_regularization_loss: 8.3368 - reconstruction_loss: 70.2775 - target_prediction_loss: 15.0448 - total_loss: 113.8730 - vae_regularisation_loss: 19.0542 - val_cluster_target_regularisation_loss: 1.1647 - val_mixture_regularization_loss: 8.3437 - val_reconstruction_loss: 75.5065 - val_target_prediction_loss: 15.4582 - val_total_loss: 119.2496 - val_vae_regularisation_loss: 18.7766
# Epoch 61/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.1578 - mixture_regularization_loss: 8.3371 - reconstruction_loss: 69.6571 - target_prediction_loss: 14.9646 - total_loss: 113.1346 - vae_regularisation_loss: 19.0181 - val_cluster_target_regularisation_loss: 1.1506 - val_mixture_regularization_loss: 8.3527 - val_reconstruction_loss: 75.2799 - val_target_prediction_loss: 15.2912 - val_total_loss: 118.8056 - val_vae_regularisation_loss: 18.7312
# Epoch 62/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 1.1585 - mixture_regularization_loss: 8.3369 - reconstruction_loss: 70.0254 - target_prediction_loss: 15.0536 - total_loss: 113.3455 - vae_regularisation_loss: 18.7710 - val_cluster_target_regularisation_loss: 1.1556 - val_mixture_regularization_loss: 8.3463 - val_reconstruction_loss: 75.3813 - val_target_prediction_loss: 15.3406 - val_total_loss: 119.1674 - val_vae_regularisation_loss: 18.9435
# Epoch 63/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - cluster_target_regularisation_loss: 1.1630 - mixture_regularization_loss: 8.3369 - reconstruction_loss: 69.5989 - target_prediction_loss: 15.0376 - total_loss: 113.1246 - vae_regularisation_loss: 18.9882 - val_cluster_target_regularisation_loss: 1.1461 - val_mixture_regularization_loss: 8.3467 - val_reconstruction_loss: 74.0270 - val_target_prediction_loss: 15.2324 - val_total_loss: 117.5669 - val_vae_regularisation_loss: 18.8148
# Epoch 64/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 1.1640 - mixture_regularization_loss: 8.3355 - reconstruction_loss: 69.2295 - target_prediction_loss: 14.9969 - total_loss: 112.6151 - vae_regularisation_loss: 18.8892 - val_cluster_target_regularisation_loss: 1.1562 - val_mixture_regularization_loss: 8.3463 - val_reconstruction_loss: 74.0718 - val_target_prediction_loss: 15.3956 - val_total_loss: 117.6159 - val_vae_regularisation_loss: 18.6460
# Epoch 65/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - cluster_target_regularisation_loss: 1.1686 - mixture_regularization_loss: 8.3375 - reconstruction_loss: 68.5822 - target_prediction_loss: 15.0213 - total_loss: 111.9450 - vae_regularisation_loss: 18.8353 - val_cluster_target_regularisation_loss: 1.1564 - val_mixture_regularization_loss: 8.3490 - val_reconstruction_loss: 75.6591 - val_target_prediction_loss: 15.3985 - val_total_loss: 119.1178 - val_vae_regularisation_loss: 18.5548
# Epoch 66/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.1681 - mixture_regularization_loss: 8.3359 - reconstruction_loss: 68.5642 - target_prediction_loss: 14.9518 - total_loss: 111.7183 - vae_regularisation_loss: 18.6983 - val_cluster_target_regularisation_loss: 1.1736 - val_mixture_regularization_loss: 8.3469 - val_reconstruction_loss: 75.0730 - val_target_prediction_loss: 15.4104 - val_total_loss: 118.5324 - val_vae_regularisation_loss: 18.5286
# Epoch 67/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 1.1744 - mixture_regularization_loss: 8.3369 - reconstruction_loss: 68.0824 - target_prediction_loss: 15.0388 - total_loss: 111.3569 - vae_regularisation_loss: 18.7245 - val_cluster_target_regularisation_loss: 1.1682 - val_mixture_regularization_loss: 8.3453 - val_reconstruction_loss: 73.0449 - val_target_prediction_loss: 15.3974 - val_total_loss: 116.7084 - val_vae_regularisation_loss: 18.7525
# Epoch 68/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.1766 - mixture_regularization_loss: 8.3376 - reconstruction_loss: 67.8240 - target_prediction_loss: 14.9852 - total_loss: 111.1517 - vae_regularisation_loss: 18.8283 - val_cluster_target_regularisation_loss: 1.1737 - val_mixture_regularization_loss: 8.3458 - val_reconstruction_loss: 73.5429 - val_target_prediction_loss: 15.3111 - val_total_loss: 117.1411 - val_vae_regularisation_loss: 18.7675
# Epoch 69/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - cluster_target_regularisation_loss: 1.1664 - mixture_regularization_loss: 8.3387 - reconstruction_loss: 68.3538 - target_prediction_loss: 14.9758 - total_loss: 111.3240 - vae_regularisation_loss: 18.4892 - val_cluster_target_regularisation_loss: 1.1692 - val_mixture_regularization_loss: 8.3467 - val_reconstruction_loss: 75.8585 - val_target_prediction_loss: 15.3905 - val_total_loss: 118.9727 - val_vae_regularisation_loss: 18.2079
# Epoch 70/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - cluster_target_regularisation_loss: 1.1732 - mixture_regularization_loss: 8.3384 - reconstruction_loss: 68.2995 - target_prediction_loss: 14.9734 - total_loss: 111.4612 - vae_regularisation_loss: 18.6766 - val_cluster_target_regularisation_loss: 1.1753 - val_mixture_regularization_loss: 8.3469 - val_reconstruction_loss: 73.7269 - val_target_prediction_loss: 15.4022 - val_total_loss: 117.1774 - val_vae_regularisation_loss: 18.5260
# Epoch 71/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 1.1817 - mixture_regularization_loss: 8.3367 - reconstruction_loss: 66.9088 - target_prediction_loss: 14.9386 - total_loss: 110.0570 - vae_regularisation_loss: 18.6913 - val_cluster_target_regularisation_loss: 1.1836 - val_mixture_regularization_loss: 8.3472 - val_reconstruction_loss: 72.5290 - val_target_prediction_loss: 15.2234 - val_total_loss: 115.8282 - val_vae_regularisation_loss: 18.5450
# Epoch 72/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - cluster_target_regularisation_loss: 1.1823 - mixture_regularization_loss: 8.3363 - reconstruction_loss: 66.7836 - target_prediction_loss: 14.9615 - total_loss: 109.8733 - vae_regularisation_loss: 18.6095 - val_cluster_target_regularisation_loss: 1.1820 - val_mixture_regularization_loss: 8.3449 - val_reconstruction_loss: 72.2700 - val_target_prediction_loss: 15.3330 - val_total_loss: 115.5037 - val_vae_regularisation_loss: 18.3738
# Epoch 73/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 1.1749 - mixture_regularization_loss: 8.3379 - reconstruction_loss: 66.9773 - target_prediction_loss: 14.9830 - total_loss: 110.2317 - vae_regularisation_loss: 18.7585 - val_cluster_target_regularisation_loss: 1.1816 - val_mixture_regularization_loss: 8.3456 - val_reconstruction_loss: 73.0502 - val_target_prediction_loss: 15.3473 - val_total_loss: 116.4063 - val_vae_regularisation_loss: 18.4816
# Epoch 74/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 1.1751 - mixture_regularization_loss: 8.3386 - reconstruction_loss: 66.7849 - target_prediction_loss: 14.9521 - total_loss: 109.8118 - vae_regularisation_loss: 18.5611 - val_cluster_target_regularisation_loss: 1.1890 - val_mixture_regularization_loss: 8.3456 - val_reconstruction_loss: 73.9819 - val_target_prediction_loss: 15.2862 - val_total_loss: 117.1468 - val_vae_regularisation_loss: 18.3440
# Epoch 75/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - cluster_target_regularisation_loss: 1.1736 - mixture_regularization_loss: 8.3379 - reconstruction_loss: 66.1372 - target_prediction_loss: 14.9040 - total_loss: 109.2752 - vae_regularisation_loss: 18.7224 - val_cluster_target_regularisation_loss: 1.1753 - val_mixture_regularization_loss: 8.3480 - val_reconstruction_loss: 70.6132 - val_target_prediction_loss: 15.2948 - val_total_loss: 113.6582 - val_vae_regularisation_loss: 18.2269
# Epoch 76/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - cluster_target_regularisation_loss: 1.1846 - mixture_regularization_loss: 8.3368 - reconstruction_loss: 64.7775 - target_prediction_loss: 14.9386 - total_loss: 107.8135 - vae_regularisation_loss: 18.5760 - val_cluster_target_regularisation_loss: 1.1975 - val_mixture_regularization_loss: 8.3477 - val_reconstruction_loss: 70.5019 - val_target_prediction_loss: 15.3975 - val_total_loss: 114.5387 - val_vae_regularisation_loss: 19.0942
# Epoch 77/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - cluster_target_regularisation_loss: 1.1749 - mixture_regularization_loss: 8.3384 - reconstruction_loss: 65.7835 - target_prediction_loss: 14.9489 - total_loss: 108.9303 - vae_regularisation_loss: 18.6845 - val_cluster_target_regularisation_loss: 1.1952 - val_mixture_regularization_loss: 8.3501 - val_reconstruction_loss: 70.8015 - val_target_prediction_loss: 15.2854 - val_total_loss: 114.3104 - val_vae_regularisation_loss: 18.6782
# Epoch 78/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - cluster_target_regularisation_loss: 1.1819 - mixture_regularization_loss: 8.3380 - reconstruction_loss: 65.4069 - target_prediction_loss: 14.8957 - total_loss: 108.3308 - vae_regularisation_loss: 18.5083 - val_cluster_target_regularisation_loss: 1.1888 - val_mixture_regularization_loss: 8.3511 - val_reconstruction_loss: 71.1535 - val_target_prediction_loss: 15.4454 - val_total_loss: 114.8709 - val_vae_regularisation_loss: 18.7320
# Epoch 79/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - cluster_target_regularisation_loss: 1.1833 - mixture_regularization_loss: 8.3389 - reconstruction_loss: 64.8596 - target_prediction_loss: 14.8220 - total_loss: 108.0654 - vae_regularisation_loss: 18.8616 - val_cluster_target_regularisation_loss: 1.1761 - val_mixture_regularization_loss: 8.3459 - val_reconstruction_loss: 69.1405 - val_target_prediction_loss: 15.4032 - val_total_loss: 112.7728 - val_vae_regularisation_loss: 18.7071
# Epoch 80/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.1763 - mixture_regularization_loss: 8.3389 - reconstruction_loss: 63.4625 - target_prediction_loss: 14.9365 - total_loss: 106.5724 - vae_regularisation_loss: 18.6581 - val_cluster_target_regularisation_loss: 1.1838 - val_mixture_regularization_loss: 8.3448 - val_reconstruction_loss: 67.9557 - val_target_prediction_loss: 15.3697 - val_total_loss: 111.4864 - val_vae_regularisation_loss: 18.6325
# Epoch 81/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 1.1791 - mixture_regularization_loss: 8.3366 - reconstruction_loss: 63.0995 - target_prediction_loss: 14.9341 - total_loss: 106.1824 - vae_regularisation_loss: 18.6330 - val_cluster_target_regularisation_loss: 1.1840 - val_mixture_regularization_loss: 8.3471 - val_reconstruction_loss: 69.9517 - val_target_prediction_loss: 15.2887 - val_total_loss: 113.4131 - val_vae_regularisation_loss: 18.6416
# Epoch 82/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - cluster_target_regularisation_loss: 1.1889 - mixture_regularization_loss: 8.3385 - reconstruction_loss: 63.9599 - target_prediction_loss: 14.8664 - total_loss: 107.2246 - vae_regularisation_loss: 18.8708 - val_cluster_target_regularisation_loss: 1.1818 - val_mixture_regularization_loss: 8.3479 - val_reconstruction_loss: 70.2313 - val_target_prediction_loss: 15.4722 - val_total_loss: 113.6160 - val_vae_regularisation_loss: 18.3830
# Epoch 83/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - cluster_target_regularisation_loss: 1.1771 - mixture_regularization_loss: 8.3377 - reconstruction_loss: 64.5237 - target_prediction_loss: 14.9122 - total_loss: 107.6688 - vae_regularisation_loss: 18.7180 - val_cluster_target_regularisation_loss: 1.1607 - val_mixture_regularization_loss: 8.3495 - val_reconstruction_loss: 68.3971 - val_target_prediction_loss: 15.3906 - val_total_loss: 111.9073 - val_vae_regularisation_loss: 18.6094
# Epoch 84/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.1695 - mixture_regularization_loss: 8.3389 - reconstruction_loss: 63.0986 - target_prediction_loss: 14.9294 - total_loss: 106.2680 - vae_regularisation_loss: 18.7315 - val_cluster_target_regularisation_loss: 1.1708 - val_mixture_regularization_loss: 8.3490 - val_reconstruction_loss: 66.8075 - val_target_prediction_loss: 15.3107 - val_total_loss: 110.5016 - val_vae_regularisation_loss: 18.8636
# Epoch 85/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 1.1734 - mixture_regularization_loss: 8.3397 - reconstruction_loss: 62.8077 - target_prediction_loss: 14.9328 - total_loss: 105.9604 - vae_regularisation_loss: 18.7067 - val_cluster_target_regularisation_loss: 1.1690 - val_mixture_regularization_loss: 8.3518 - val_reconstruction_loss: 69.0176 - val_target_prediction_loss: 15.3013 - val_total_loss: 112.4699 - val_vae_regularisation_loss: 18.6301
# Epoch 86/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - cluster_target_regularisation_loss: 1.1662 - mixture_regularization_loss: 8.3383 - reconstruction_loss: 61.5568 - target_prediction_loss: 14.9627 - total_loss: 104.7865 - vae_regularisation_loss: 18.7624 - val_cluster_target_regularisation_loss: 1.1597 - val_mixture_regularization_loss: 8.3460 - val_reconstruction_loss: 67.5103 - val_target_prediction_loss: 15.3312 - val_total_loss: 110.8639 - val_vae_regularisation_loss: 18.5166
# Epoch 87/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 1.1827 - mixture_regularization_loss: 8.3400 - reconstruction_loss: 62.4839 - target_prediction_loss: 14.9549 - total_loss: 105.7395 - vae_regularisation_loss: 18.7782 - val_cluster_target_regularisation_loss: 1.1736 - val_mixture_regularization_loss: 8.3466 - val_reconstruction_loss: 67.2999 - val_target_prediction_loss: 15.2208 - val_total_loss: 110.3110 - val_vae_regularisation_loss: 18.2702
# Epoch 88/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - cluster_target_regularisation_loss: 1.1768 - mixture_regularization_loss: 8.3380 - reconstruction_loss: 61.6549 - target_prediction_loss: 14.9664 - total_loss: 104.8701 - vae_regularisation_loss: 18.7341 - val_cluster_target_regularisation_loss: 1.1796 - val_mixture_regularization_loss: 8.3478 - val_reconstruction_loss: 66.8409 - val_target_prediction_loss: 15.2427 - val_total_loss: 110.2437 - val_vae_regularisation_loss: 18.6326
# Epoch 89/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - cluster_target_regularisation_loss: 1.1726 - mixture_regularization_loss: 8.3379 - reconstruction_loss: 61.4622 - target_prediction_loss: 14.8623 - total_loss: 104.4549 - vae_regularisation_loss: 18.6199 - val_cluster_target_regularisation_loss: 1.1744 - val_mixture_regularization_loss: 8.3445 - val_reconstruction_loss: 65.8713 - val_target_prediction_loss: 15.2493 - val_total_loss: 109.0418 - val_vae_regularisation_loss: 18.4023
# Epoch 90/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 1.1813 - mixture_regularization_loss: 8.3382 - reconstruction_loss: 61.1860 - target_prediction_loss: 14.8376 - total_loss: 104.2341 - vae_regularisation_loss: 18.6911 - val_cluster_target_regularisation_loss: 1.1843 - val_mixture_regularization_loss: 8.3516 - val_reconstruction_loss: 67.1031 - val_target_prediction_loss: 15.2702 - val_total_loss: 110.5715 - val_vae_regularisation_loss: 18.6623
# Epoch 91/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - cluster_target_regularisation_loss: 1.1817 - mixture_regularization_loss: 8.3411 - reconstruction_loss: 61.4309 - target_prediction_loss: 14.8133 - total_loss: 104.3072 - vae_regularisation_loss: 18.5401 - val_cluster_target_regularisation_loss: 1.1820 - val_mixture_regularization_loss: 8.3478 - val_reconstruction_loss: 65.8157 - val_target_prediction_loss: 15.2858 - val_total_loss: 109.5164 - val_vae_regularisation_loss: 18.8851
# Epoch 92/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 1.1766 - mixture_regularization_loss: 8.3377 - reconstruction_loss: 60.7906 - target_prediction_loss: 14.9222 - total_loss: 104.1217 - vae_regularisation_loss: 18.8947 - val_cluster_target_regularisation_loss: 1.1743 - val_mixture_regularization_loss: 8.3506 - val_reconstruction_loss: 67.6205 - val_target_prediction_loss: 15.2550 - val_total_loss: 110.9747 - val_vae_regularisation_loss: 18.5744
# Epoch 93/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 1.1742 - mixture_regularization_loss: 8.3391 - reconstruction_loss: 60.8199 - target_prediction_loss: 14.8232 - total_loss: 103.9473 - vae_regularisation_loss: 18.7909 - val_cluster_target_regularisation_loss: 1.1675 - val_mixture_regularization_loss: 8.3529 - val_reconstruction_loss: 65.5505 - val_target_prediction_loss: 15.4091 - val_total_loss: 109.4136 - val_vae_regularisation_loss: 18.9336
# Epoch 94/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 1.1716 - mixture_regularization_loss: 8.3375 - reconstruction_loss: 60.5708 - target_prediction_loss: 14.8608 - total_loss: 103.6809 - vae_regularisation_loss: 18.7402 - val_cluster_target_regularisation_loss: 1.1533 - val_mixture_regularization_loss: 8.3479 - val_reconstruction_loss: 66.4458 - val_target_prediction_loss: 15.2385 - val_total_loss: 109.9504 - val_vae_regularisation_loss: 18.7649
# Epoch 95/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - cluster_target_regularisation_loss: 1.1699 - mixture_regularization_loss: 8.3409 - reconstruction_loss: 60.1725 - target_prediction_loss: 14.8604 - total_loss: 103.3686 - vae_regularisation_loss: 18.8248 - val_cluster_target_regularisation_loss: 1.1666 - val_mixture_regularization_loss: 8.3539 - val_reconstruction_loss: 64.4909 - val_target_prediction_loss: 15.3281 - val_total_loss: 107.4656 - val_vae_regularisation_loss: 18.1260
# Epoch 96/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 1.1701 - mixture_regularization_loss: 8.3388 - reconstruction_loss: 59.9523 - target_prediction_loss: 14.8114 - total_loss: 102.8677 - vae_regularisation_loss: 18.5950 - val_cluster_target_regularisation_loss: 1.1692 - val_mixture_regularization_loss: 8.3512 - val_reconstruction_loss: 65.6657 - val_target_prediction_loss: 15.4071 - val_total_loss: 109.1133 - val_vae_regularisation_loss: 18.5201
# Epoch 97/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 1.1655 - mixture_regularization_loss: 8.3377 - reconstruction_loss: 60.0527 - target_prediction_loss: 14.7943 - total_loss: 103.1454 - vae_regularisation_loss: 18.7953 - val_cluster_target_regularisation_loss: 1.1431 - val_mixture_regularization_loss: 8.3496 - val_reconstruction_loss: 65.5041 - val_target_prediction_loss: 15.2692 - val_total_loss: 108.7330 - val_vae_regularisation_loss: 18.4670
# Epoch 98/500
# ...
# Epoch 469/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 0.7730 - mixture_regularization_loss: 8.3364 - reconstruction_loss: 38.4509 - target_prediction_loss: 14.6728 - total_loss: 80.5508 - vae_regularisation_loss: 18.3177 - val_cluster_target_regularisation_loss: 0.7969 - val_mixture_regularization_loss: 8.3418 - val_reconstruction_loss: 51.6450 - val_target_prediction_loss: 15.3751 - val_total_loss: 94.8092 - val_vae_regularisation_loss: 18.6504
# Epoch 470/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7884 - mixture_regularization_loss: 8.3370 - reconstruction_loss: 38.7862 - target_prediction_loss: 14.6015 - total_loss: 80.9383 - vae_regularisation_loss: 18.4252 - val_cluster_target_regularisation_loss: 0.8034 - val_mixture_regularization_loss: 8.3416 - val_reconstruction_loss: 52.3106 - val_target_prediction_loss: 15.3348 - val_total_loss: 95.1593 - val_vae_regularisation_loss: 18.3689
# Epoch 471/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7828 - mixture_regularization_loss: 8.3361 - reconstruction_loss: 39.1634 - target_prediction_loss: 14.6291 - total_loss: 81.3653 - vae_regularisation_loss: 18.4539 - val_cluster_target_regularisation_loss: 0.7769 - val_mixture_regularization_loss: 8.3430 - val_reconstruction_loss: 52.4943 - val_target_prediction_loss: 15.4064 - val_total_loss: 95.5200 - val_vae_regularisation_loss: 18.4994
# Epoch 472/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 0.7865 - mixture_regularization_loss: 8.3349 - reconstruction_loss: 38.6379 - target_prediction_loss: 14.6372 - total_loss: 80.8209 - vae_regularisation_loss: 18.4244 - val_cluster_target_regularisation_loss: 0.8091 - val_mixture_regularization_loss: 8.3422 - val_reconstruction_loss: 51.6544 - val_target_prediction_loss: 15.2613 - val_total_loss: 94.4590 - val_vae_regularisation_loss: 18.3919
# Epoch 473/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 0.7925 - mixture_regularization_loss: 8.3360 - reconstruction_loss: 38.0571 - target_prediction_loss: 14.5783 - total_loss: 80.2012 - vae_regularisation_loss: 18.4373 - val_cluster_target_regularisation_loss: 0.7971 - val_mixture_regularization_loss: 8.3429 - val_reconstruction_loss: 50.7870 - val_target_prediction_loss: 15.1668 - val_total_loss: 93.4579 - val_vae_regularisation_loss: 18.3642
# Epoch 474/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 0.8079 - mixture_regularization_loss: 8.3351 - reconstruction_loss: 38.7343 - target_prediction_loss: 14.7502 - total_loss: 81.0177 - vae_regularisation_loss: 18.3903 - val_cluster_target_regularisation_loss: 0.7997 - val_mixture_regularization_loss: 8.3416 - val_reconstruction_loss: 52.0079 - val_target_prediction_loss: 15.3897 - val_total_loss: 94.9479 - val_vae_regularisation_loss: 18.4090
# Epoch 475/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 0.7845 - mixture_regularization_loss: 8.3365 - reconstruction_loss: 37.9487 - target_prediction_loss: 14.6734 - total_loss: 80.1264 - vae_regularisation_loss: 18.3833 - val_cluster_target_regularisation_loss: 0.7822 - val_mixture_regularization_loss: 8.3433 - val_reconstruction_loss: 50.4545 - val_target_prediction_loss: 15.2784 - val_total_loss: 93.2510 - val_vae_regularisation_loss: 18.3925
# Epoch 476/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - cluster_target_regularisation_loss: 0.7604 - mixture_regularization_loss: 8.3365 - reconstruction_loss: 38.8938 - target_prediction_loss: 14.6258 - total_loss: 81.0796 - vae_regularisation_loss: 18.4631 - val_cluster_target_regularisation_loss: 0.7939 - val_mixture_regularization_loss: 8.3417 - val_reconstruction_loss: 50.9443 - val_target_prediction_loss: 15.3812 - val_total_loss: 93.9715 - val_vae_regularisation_loss: 18.5105
# Epoch 477/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 0.7945 - mixture_regularization_loss: 8.3351 - reconstruction_loss: 38.5423 - target_prediction_loss: 14.6011 - total_loss: 80.6289 - vae_regularisation_loss: 18.3559 - val_cluster_target_regularisation_loss: 0.7949 - val_mixture_regularization_loss: 8.3424 - val_reconstruction_loss: 51.1717 - val_target_prediction_loss: 15.2744 - val_total_loss: 93.8150 - val_vae_regularisation_loss: 18.2315
# Epoch 478/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7852 - mixture_regularization_loss: 8.3376 - reconstruction_loss: 38.2312 - target_prediction_loss: 14.6445 - total_loss: 80.4552 - vae_regularisation_loss: 18.4567 - val_cluster_target_regularisation_loss: 0.7851 - val_mixture_regularization_loss: 8.3402 - val_reconstruction_loss: 51.3381 - val_target_prediction_loss: 15.2464 - val_total_loss: 94.0444 - val_vae_regularisation_loss: 18.3346
# Epoch 479/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - cluster_target_regularisation_loss: 0.7973 - mixture_regularization_loss: 8.3356 - reconstruction_loss: 38.5064 - target_prediction_loss: 14.6419 - total_loss: 80.6255 - vae_regularisation_loss: 18.3443 - val_cluster_target_regularisation_loss: 0.7781 - val_mixture_regularization_loss: 8.3413 - val_reconstruction_loss: 51.2742 - val_target_prediction_loss: 15.2031 - val_total_loss: 93.8003 - val_vae_regularisation_loss: 18.2036
# Epoch 480/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 0.7891 - mixture_regularization_loss: 8.3345 - reconstruction_loss: 38.0286 - target_prediction_loss: 14.5972 - total_loss: 80.2038 - vae_regularisation_loss: 18.4543 - val_cluster_target_regularisation_loss: 0.8154 - val_mixture_regularization_loss: 8.3424 - val_reconstruction_loss: 52.0762 - val_target_prediction_loss: 15.3484 - val_total_loss: 94.9508 - val_vae_regularisation_loss: 18.3685
# Epoch 481/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7704 - mixture_regularization_loss: 8.3347 - reconstruction_loss: 38.3220 - target_prediction_loss: 14.5846 - total_loss: 80.3261 - vae_regularisation_loss: 18.3144 - val_cluster_target_regularisation_loss: 0.7954 - val_mixture_regularization_loss: 8.3444 - val_reconstruction_loss: 51.8834 - val_target_prediction_loss: 15.4115 - val_total_loss: 94.6436 - val_vae_regularisation_loss: 18.2088
# Epoch 482/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7831 - mixture_regularization_loss: 8.3353 - reconstruction_loss: 38.3493 - target_prediction_loss: 14.6235 - total_loss: 80.4293 - vae_regularisation_loss: 18.3380 - val_cluster_target_regularisation_loss: 0.7954 - val_mixture_regularization_loss: 8.3436 - val_reconstruction_loss: 50.4847 - val_target_prediction_loss: 15.1821 - val_total_loss: 93.2941 - val_vae_regularisation_loss: 18.4882
# Epoch 483/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - cluster_target_regularisation_loss: 0.7904 - mixture_regularization_loss: 8.3359 - reconstruction_loss: 37.6615 - target_prediction_loss: 14.5866 - total_loss: 79.9958 - vae_regularisation_loss: 18.6214 - val_cluster_target_regularisation_loss: 0.8123 - val_mixture_regularization_loss: 8.3405 - val_reconstruction_loss: 51.6037 - val_target_prediction_loss: 15.3682 - val_total_loss: 94.5315 - val_vae_regularisation_loss: 18.4068
# Epoch 484/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - cluster_target_regularisation_loss: 0.7693 - mixture_regularization_loss: 8.3361 - reconstruction_loss: 37.7510 - target_prediction_loss: 14.6997 - total_loss: 80.0665 - vae_regularisation_loss: 18.5104 - val_cluster_target_regularisation_loss: 0.8021 - val_mixture_regularization_loss: 8.3415 - val_reconstruction_loss: 51.1219 - val_target_prediction_loss: 15.2680 - val_total_loss: 94.2473 - val_vae_regularisation_loss: 18.7137
# Epoch 485/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 0.7820 - mixture_regularization_loss: 8.3363 - reconstruction_loss: 38.5244 - target_prediction_loss: 14.5239 - total_loss: 80.6257 - vae_regularisation_loss: 18.4591 - val_cluster_target_regularisation_loss: 0.7816 - val_mixture_regularization_loss: 8.3459 - val_reconstruction_loss: 52.2958 - val_target_prediction_loss: 15.2725 - val_total_loss: 94.9978 - val_vae_regularisation_loss: 18.3020
# Epoch 486/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 0.7822 - mixture_regularization_loss: 8.3363 - reconstruction_loss: 37.8082 - target_prediction_loss: 14.6427 - total_loss: 79.9640 - vae_regularisation_loss: 18.3946 - val_cluster_target_regularisation_loss: 0.7908 - val_mixture_regularization_loss: 8.3436 - val_reconstruction_loss: 51.1522 - val_target_prediction_loss: 15.2640 - val_total_loss: 93.6099 - val_vae_regularisation_loss: 18.0593
# Epoch 487/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7888 - mixture_regularization_loss: 8.3374 - reconstruction_loss: 37.5105 - target_prediction_loss: 14.5733 - total_loss: 79.5910 - vae_regularisation_loss: 18.3809 - val_cluster_target_regularisation_loss: 0.7710 - val_mixture_regularization_loss: 8.3418 - val_reconstruction_loss: 52.0215 - val_target_prediction_loss: 15.1953 - val_total_loss: 94.3750 - val_vae_regularisation_loss: 18.0454
# Epoch 488/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 0.7857 - mixture_regularization_loss: 8.3377 - reconstruction_loss: 38.4730 - target_prediction_loss: 14.6256 - total_loss: 80.7819 - vae_regularisation_loss: 18.5599 - val_cluster_target_regularisation_loss: 0.7986 - val_mixture_regularization_loss: 8.3436 - val_reconstruction_loss: 51.1663 - val_target_prediction_loss: 15.1944 - val_total_loss: 93.8852 - val_vae_regularisation_loss: 18.3823
# Epoch 489/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 0.7936 - mixture_regularization_loss: 8.3363 - reconstruction_loss: 38.0331 - target_prediction_loss: 14.6384 - total_loss: 80.2087 - vae_regularisation_loss: 18.4074 - val_cluster_target_regularisation_loss: 0.7747 - val_mixture_regularization_loss: 8.3442 - val_reconstruction_loss: 51.3600 - val_target_prediction_loss: 15.2850 - val_total_loss: 94.0202 - val_vae_regularisation_loss: 18.2563
# Epoch 490/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7691 - mixture_regularization_loss: 8.3368 - reconstruction_loss: 38.8320 - target_prediction_loss: 14.6468 - total_loss: 81.0280 - vae_regularisation_loss: 18.4433 - val_cluster_target_regularisation_loss: 0.7785 - val_mixture_regularization_loss: 8.3437 - val_reconstruction_loss: 49.8472 - val_target_prediction_loss: 15.3766 - val_total_loss: 92.9175 - val_vae_regularisation_loss: 18.5715
# Epoch 491/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7714 - mixture_regularization_loss: 8.3366 - reconstruction_loss: 38.3373 - target_prediction_loss: 14.6029 - total_loss: 80.4236 - vae_regularisation_loss: 18.3754 - val_cluster_target_regularisation_loss: 0.7724 - val_mixture_regularization_loss: 8.3429 - val_reconstruction_loss: 51.2057 - val_target_prediction_loss: 15.4038 - val_total_loss: 94.2735 - val_vae_regularisation_loss: 18.5488
# Epoch 492/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - cluster_target_regularisation_loss: 0.7659 - mixture_regularization_loss: 8.3352 - reconstruction_loss: 37.3964 - target_prediction_loss: 14.6663 - total_loss: 79.6420 - vae_regularisation_loss: 18.4782 - val_cluster_target_regularisation_loss: 0.7842 - val_mixture_regularization_loss: 8.3393 - val_reconstruction_loss: 50.1344 - val_target_prediction_loss: 15.4149 - val_total_loss: 93.0996 - val_vae_regularisation_loss: 18.4268
# Epoch 493/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7635 - mixture_regularization_loss: 8.3356 - reconstruction_loss: 38.2616 - target_prediction_loss: 14.6094 - total_loss: 80.3482 - vae_regularisation_loss: 18.3781 - val_cluster_target_regularisation_loss: 0.7587 - val_mixture_regularization_loss: 8.3417 - val_reconstruction_loss: 51.8227 - val_target_prediction_loss: 15.3537 - val_total_loss: 94.8579 - val_vae_regularisation_loss: 18.5811
# Epoch 494/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7498 - mixture_regularization_loss: 8.3357 - reconstruction_loss: 38.0872 - target_prediction_loss: 14.5556 - total_loss: 80.2406 - vae_regularisation_loss: 18.5123 - val_cluster_target_regularisation_loss: 0.7776 - val_mixture_regularization_loss: 8.3421 - val_reconstruction_loss: 51.9565 - val_target_prediction_loss: 15.3498 - val_total_loss: 94.8348 - val_vae_regularisation_loss: 18.4088
# Epoch 495/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7663 - mixture_regularization_loss: 8.3376 - reconstruction_loss: 37.6468 - target_prediction_loss: 14.6123 - total_loss: 79.7517 - vae_regularisation_loss: 18.3888 - val_cluster_target_regularisation_loss: 0.7745 - val_mixture_regularization_loss: 8.3398 - val_reconstruction_loss: 50.0351 - val_target_prediction_loss: 15.1853 - val_total_loss: 92.8963 - val_vae_regularisation_loss: 18.5617
# Epoch 496/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - cluster_target_regularisation_loss: 0.7780 - mixture_regularization_loss: 8.3366 - reconstruction_loss: 37.3423 - target_prediction_loss: 14.6047 - total_loss: 79.5161 - vae_regularisation_loss: 18.4544 - val_cluster_target_regularisation_loss: 0.7752 - val_mixture_regularization_loss: 8.3442 - val_reconstruction_loss: 50.8194 - val_target_prediction_loss: 15.3114 - val_total_loss: 93.4051 - val_vae_regularisation_loss: 18.1548
# Epoch 497/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - cluster_target_regularisation_loss: 0.7839 - mixture_regularization_loss: 8.3363 - reconstruction_loss: 37.7526 - target_prediction_loss: 14.6528 - total_loss: 79.8066 - vae_regularisation_loss: 18.2809 - val_cluster_target_regularisation_loss: 0.7821 - val_mixture_regularization_loss: 8.3448 - val_reconstruction_loss: 49.8627 - val_target_prediction_loss: 15.2017 - val_total_loss: 92.6439 - val_vae_regularisation_loss: 18.4526
# Epoch 498/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - cluster_target_regularisation_loss: 0.7565 - mixture_regularization_loss: 8.3366 - reconstruction_loss: 38.2758 - target_prediction_loss: 14.6932 - total_loss: 80.5184 - vae_regularisation_loss: 18.4563 - val_cluster_target_regularisation_loss: 0.7955 - val_mixture_regularization_loss: 8.3436 - val_reconstruction_loss: 49.9126 - val_target_prediction_loss: 15.2881 - val_total_loss: 92.9214 - val_vae_regularisation_loss: 18.5816
# Epoch 499/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - cluster_target_regularisation_loss: 0.7805 - mixture_regularization_loss: 8.3361 - reconstruction_loss: 37.5635 - target_prediction_loss: 14.6076 - total_loss: 79.6681 - vae_regularisation_loss: 18.3805 - val_cluster_target_regularisation_loss: 0.7745 - val_mixture_regularization_loss: 8.3443 - val_reconstruction_loss: 52.0597 - val_target_prediction_loss: 15.1116 - val_total_loss: 94.5270 - val_vae_regularisation_loss: 18.2369
# Epoch 500/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - cluster_target_regularisation_loss: 0.7784 - mixture_regularization_loss: 8.3355 - reconstruction_loss: 37.8793 - target_prediction_loss: 14.5954 - total_loss: 80.0445 - vae_regularisation_loss: 18.4559 - val_cluster_target_regularisation_loss: 0.7673 - val_mixture_regularization_loss: 8.3415 - val_reconstruction_loss: 52.3113 - val_target_prediction_loss: 15.1696 - val_total_loss: 94.7351 - val_vae_regularisation_loss: 18.1454

# %%
number = 0

training_loss = histories[number].history['total_loss']
validation_loss = histories[number].history['val_total_loss']
utils.plot_losses(training_loss, validation_loss)
